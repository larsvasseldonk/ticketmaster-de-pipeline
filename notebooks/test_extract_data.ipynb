# %% [markdown]
# # Imports

# %%
import requests
import os

# %% [markdown]
# ## Get API key
#
# Make sure to set the API key as a environment variable in your system:
#
# For Ubuntu:
# - `export TICKETMASTER_API_KEY="LXVLySLQxPIExSYz"`
#
# With Python:
# - `os.environ["TICKETMASTER_API_KEY"] = "YOUR_API_KEY"`

# %%
os.environ["TICKETMASTER_API_KEY"] = "xkwIHOr5jYGxFVPOCeIF9JMeP2YPjQzH"

# %%
API_KEY = os.environ.get("TICKETMASTER_API_KEY")
BASE_URL = "https://app.ticketmaster.com/discovery/v2"

if API_KEY is None:
    raise ValueError("Please set the TICKETMASTER_API_KEY environment variable.")

# %%
API_KEY
# Out:
# 'xkwIHOr5jYGxFVPOCeIF9JMeP2YPjQzH'

# %% [markdown]
# ## Get events with requests package

# %%
url = f"{BASE_URL}/events.json"

# Set the parameters for the request
params = {
    "size": 5,
    "countryCode": "NL",
    "city": "Eindhoven",
    "radius": 50,
    "unit": "km",
    "apikey": API_KEY
}

# Make the GET request to the Ticketmaster API
response = requests.get(url, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Parse and print the JSON response
    data = response.json()
    print(data)
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# {'_embedded': {'events': [{'name': 'Allman Brown', 'type': 'event', 'id': 'Z698xZbpZ17Ga0g', 'test': False, 'url': 'https://www.ticketmaster.nl/event/allman-brown-tickets/309935?language=en-us', 'locale': 'en-us', 'images': [{'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_SOURCE', 'width': 1440, 'height': 810, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/c/677/c58dd0af-cda8-49b2-bdaf-068540c3a677_106541_TABLET_LANDSCAPE_LARGE_16_9.jpg', 'width': 2048, 'height': 1152, 'fallback': True}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RETINA_PORTRAIT_3_2.jpg', 'width': 640, 'height': 427, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_ARTIST_PAGE_3_2.jpg', 'width': 305, 'height': 203, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_TABLET_LANDSCAPE_3_2.jpg', 'width': 1024, 'height': 683, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RETINA_LANDSCAPE_16_9.jpg', 'width': 1136, 'height': 639, 'fallback': False}, {'ratio': '4_3', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_CUSTOM.jpg', 'width': 305, 'height': 225, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_TABLET_LANDSCAPE_16_9.jpg', 'width': 1024, 'height': 576, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_EVENT_DETAIL_PAGE_16_9.jpg', 'width': 205, 'height': 115, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RETINA_PORTRAIT_16_9.jpg', 'width': 640, 'height': 360, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RECOMENDATION_16_9.jpg', 'width': 100, 'height': 56, 'fallback': False}], 'sales': {'public': {'startDateTime': '2024-10-11T08:00:00Z', 'startTBD': False, 'startTBA': False, 'endDateTime': '2025-04-12T21:30:00Z'}}, 'dates': {'start': {'localDate': '2025-04-12', 'localTime': '20:00:00', 'dateTime': '2025-04-12T18:00:00Z', 'dateTBD': False, 'dateTBA': False, 'timeTBA': False, 'noSpecificTime': False}, 'timezone': 'Europe/Amsterdam', 'status': {'code': 'onsale'}, 'spanMultipleDays': False}, 'classifications': [{'primary': True, 'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'}, 'genre': {'id': 'KnvZfZ7vAvl', 'name': 'Other'}, 'subGenre': {'id': 'KZazBEonSMnZfZ7vk1I', 'name': 'Other'}, 'family': False}], 'promoter': {'id': '3049', 'name': 'De Effenaar'}, 'promoters': [{'id': '3049', 'name': 'De Effenaar'}], 'seatmap': {'staticUrl': 'https://media.ticketmaster.eu/netherlands/d195eae8433e4ffa15240f13c4d888a8.jpg', 'id': 'seatmap'}, 'ticketing': {'safeTix': {'enabled': False}, 'id': 'ticketing'}, '_links': {'self': {'href': '/discovery/v2/events/Z698xZbpZ17Ga0g?locale=en-us'}, 'attractions': [{'href': '/discovery/v2/attractions/K8vZ917pYgf?locale=en-us'}], 'venues': [{'href': '/discovery/v2/venues/Z598xZbpZA717?locale=en-us'}]}, '_embedded': {'venues': [{'name': "Café 't Rozenknopje", 'type': 'venue', 'id': 'Z598xZbpZA717', 'test': False, 'url': 'https://www.ticketmaster.nl/venue/cafe-t-rozenknopje-eindhoven-tickets/rozen/115', 'locale': 'en-us', 'images': [{'ratio': '16_9', 'url': 'https://media.ticketmaster.eu/netherlands/978a260381e7b83fd87879264597d784.png', 'width': 205, 'height': 115, 'fallback': False}], 'postalCode': '5615 PA', 'timezone': 'Europe/Amsterdam', 'city': {'name': 'Eindhoven'}, 'country': {'name': 'Netherlands', 'countryCode': 'NL'}, 'address': {'line1': 'Hoogstraat 59'}, 'location': {'longitude': '5.47156', 'latitude': '51.43338'}, 'upcomingEvents': {'mfx-nl': 4, '_total': 4, '_filtered': 0}, '_links': {'self': {'href': '/d ...

# %%
data["page"]
# Out:
# {'size': 5, 'totalElements': 18, 'totalPages': 4, 'number': 0}

# %%
data["_embedded"]["events"][1]
# Out:
# {'name': 'James Leg',
#  'type': 'event',
#  'id': 'Z698xZbpZ17GF-t',
#  'test': False,
#  'url': 'https://www.ticketmaster.nl/event/james-leg-tickets/308869?language=en-us',
#  'locale': 'en-us',
#  'images': [{'ratio': '4_3',
#    'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_CUSTOM.jpg',
#    'width': 305,
#    'height': 225,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_RECOMENDATION_16_9.jpg',
#    'width': 100,
#    'height': 56,
#    'fallback': False},
#   {'ratio': '1_1',
#    'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_SOURCE',
#    'width': 720,
#    'height': 720,
#    'fallback': False},
#   {'ratio': '3_2',
#    'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_ARTIST_PAGE_3_2.jpg',
#    'width': 305,
#    'height': 203,
#    'fallback': False},
#   {'ratio': '3_2',
#    'url': 'https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_TABLET_LANDSCAPE_3_2.jpg',
#    'width': 1024,
#    'height': 683,
#    'fallback': True},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_RETINA_LANDSCAPE_16_9.jpg',
#    'width': 1136,
#    'height': 639,
#    'fallback': True},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_RETINA_PORTRAIT_16_9.jpg',
#    'width': 640,
#    'height': 360,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#    'width': 2048,
#    'height': 1152,
#    'fallback': True},
#   {'ratio': '3_2',
#    'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_RETINA_PORTRAIT_3_2.jpg',
#    'width': 640,
#    'height': 427,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_TABLET_LANDSCAPE_16_9.jpg',
#    'width': 1024,
#    'height': 576,
#    'fallback': True},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_EVENT_DETAIL_PAGE_16_9.jpg',
#    'width': 205,
#    'height': 115,
#    'fallback': False}],
#  'sales': {'public': {'startDateTime': '2024-09-10T08:00:00Z',
#    'startTBD': False,
#    'startTBA': False,
#    'endDateTime': '2025-04-24T21:00:00Z'}},
#  'dates': {'start': {'localDate': '2025-04-24',
#    'localTime': '20:30:00',
#    'dateTime': '2025-04-24T18:30:00Z',
#    'dateTBD': False,
#    'dateTBA': False,
#    'timeTBA': False,
#    'noSpecificTime': False},
#   'timezone': 'Europe/Amsterdam',
#   'status': {'code': 'onsale'},
#   'spanMultipleDays': False},
#  'classifications': [{'primary': True,
#    'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#    'genre': {'id': 'KnvZfZ7vAvl', 'name': 'Other'},
#    'subGenre': {'id': 'KZazBEonSMnZfZ7vk1I', 'name': 'Other'},
#    'family': False}],
#  'promoter': {'id': '3049', 'name': 'De Effenaar'},
#  'promoters': [{'id': '3049', 'name': 'De Effenaar'}],
#  'seatmap': {'staticUrl': 'https://media.ticketmaster.eu/netherlands/8955f6705b4384b3c3bc05e10815ecf3.jpg',
#   'id': 'seatmap'},
#  'ticketing': {'safeTix': {'enabled': False}, 'id': 'ticketing'},
#  '_links': {'self': {'href': '/discovery/v2/events/Z698xZbpZ17GF-t?locale=en-us'},
#   'attractions': [{'href': '/discovery/v2/attractions/K8vZ91721T7?locale=en-us'}],
#   'venues': [{'href': '/discovery/v2/venues/Z598xZbpZ77v7?locale=en-us'}]},
#  '_embedded': {'venues': [{'name': 'Cafe Wilhelmina',
#     'type': 'venue',
#     'id': 'Z598xZbpZ77v7',
#     'test': False,
#     'url': 'https://www.ticketmaster.nl/venue/cafe-wilhelmina-eindhoven-tickets/wilhelmina/115',
#     'locale': 'en-us',
#     'images': [{'ratio': '16_9',
#       'url': 'https://media.ticketmaster.eu/netherlands/b428b4403d881478983fbdf257eaed2e.png',
#       'width': 205,
#       'height': 115,
#       'fallback': False}],
#     'postalCode': '5611 HE',
#     'timezone': 'Europe/Amsterdam',
#     'city': {'name': 'Eindhoven'},
#     'country': {'name': 'Netherlands', 'countryCode': 'NL'},
#     'address': {'line1': 'Wilhelminaplein 6'},
#     'location': {'longitude': '5.4718', 'latitude': '51.43788'},
#     'upcomingEvents': {'mfx-nl': 4, '_total': 4, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/Z598xZbpZ77v7?locale=en-us'}}}],
#   'attractions': [{'name': 'James Leg',
#     'type': 'attraction',
#     'id': 'K8vZ91721T7',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/james-leg-tickets/artist/1663666',
#     'locale': 'en-us',
#     'externalLinks': {'musicbrainz': [{'id': '54596cfb-0e41-4526-b667-547b071cbb64'}]},
#     'images': [{'ratio': '4_3',
#       'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_CUSTOM.jpg',
#       'width': 305,
#       'height': 225,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_RECOMENDATION_16_9.jpg',
#       'width': 100,
#       'height': 56,
#       'fallback': False},
#      {'ratio': '1_1',
#       'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_SOURCE',
#       'width': 720,
#       'height': 720,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_TABLET_LANDSCAPE_3_2.jpg',
#       'width': 1024,
#       'height': 683,
#       'fallback': True},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_RETINA_LANDSCAPE_16_9.jpg',
#       'width': 1136,
#       'height': 639,
#       'fallback': True},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_RETINA_PORTRAIT_16_9.jpg',
#       'width': 640,
#       'height': 360,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#       'width': 2048,
#       'height': 1152,
#       'fallback': True},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_RETINA_PORTRAIT_3_2.jpg',
#       'width': 640,
#       'height': 427,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_TABLET_LANDSCAPE_16_9.jpg',
#       'width': 1024,
#       'height': 576,
#       'fallback': True},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_EVENT_DETAIL_PAGE_16_9.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False}],
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#       'genre': {'id': 'KnvZfZ7vAeA', 'name': 'Rock'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7v6dt', 'name': 'Alternative Rock'},
#       'type': {'id': 'KZAyXgnZfZ7v7nI', 'name': 'Undefined'},
#       'subType': {'id': 'KZFzBErXgnZfZ7v7lJ', 'name': 'Undefined'},
#       'family': False}],
#     'upcomingEvents': {'mfx-nl': 2, '_total': 2, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ91721T7?locale=en-us'}}}]}}

# %% [markdown]
# ## Get events locally

# %%
import requests
import os
import json
import datetime

BASE_API_URL = "https://app.ticketmaster.com/discovery/v2"
EVENTS_ENDPOINT = f"{BASE_API_URL}/events.json"
MAX_PAGES = 1
PAGE_SIZE = 20


def paginated_getter(api_key: str, events_until: datetime.date, country_code: str = "NL"):
    """Generator function to retrieve paginated events from Ticketmaster API."""
    page_number = 1

    while page_number <= MAX_PAGES:
        params = {
            "page": page_number,
            "size": PAGE_SIZE,
            "countryCode": country_code,
            "endDateTime": events_until.strftime("%Y-%m-%dT%H:%M:%SZ"),
            "apikey": api_key
        }

        try:
            response = requests.get(EVENTS_ENDPOINT, params=params)
            response.raise_for_status()
            page_json = response.json()
            events = page_json.get("_embedded", {}).get("events", [])

            if not events:
                print(f'No more events available after page {page_number}.')
                break

            yield page_json
            print(f'Retrieved page {page_number} with {len(events)} event(s).')

            page_number += 1

        except requests.exceptions.HTTPError as e:
            print(f"HTTP error occurred: {e}")
            break
        except requests.exceptions.RequestException as e:
            print(f"Request exception occurred: {e}")
            break


def save_events_to_file(data, directory, filename):
    """Save the event data to a JSON file."""

    file_path = os.path.join(directory, filename)
    with open(file_path, 'w') as json_file:
        json.dump(data, json_file, indent=4)

    print(f"Data successfully written to {file_path}")
    
    return file_path


import sys
import urllib.request
from concurrent.futures import ThreadPoolExecutor
from google.cloud import storage
from google.api_core.exceptions import NotFound, Forbidden
import time

# Change this to your bucket name
BUCKET_NAME = "ticketmaster_bucket"

# If you authenticated through the GCP SDK you can comment out these two lines
CREDENTIALS_FILE = os.environ["GOOGLE_APPLICATION_CREDENTIALS"]
client = storage.Client.from_service_account_json(CREDENTIALS_FILE)

bucket = client.bucket(BUCKET_NAME)

def verify_gcs_upload(blob_name):
    return storage.Blob(bucket=bucket, name=blob_name).exists(client)

def upload_to_gcs(file_path, max_retries=3):
    blob_name = os.path.basename(file_path)
    blob = bucket.blob(blob_name)

    for attempt in range(max_retries):
        try:
            print(f"Uploading {file_path} to {BUCKET_NAME} (Attempt {attempt + 1})...")
            blob.upload_from_filename(file_path)
            print(f"Uploaded: gs://{BUCKET_NAME}/{blob_name}")

            if verify_gcs_upload(blob_name):
                print(f"Verification successful for {blob_name}")
                return
            else:
                print(f"Verification failed for {blob_name}, retrying...")

        except Exception as e:
            print(f"Failed to upload {file_path} to GCS: {e}")

        time.sleep(5)

    print(f"Giving up on {file_path} after {max_retries} attempts.")


def main():
    api_key = os.environ.get("TICKETMASTER_API_KEY")
    country_code = "NL"
    data_dir = "data"

    cities = ["Eindhoven", "Amsterdam"]
    today = datetime.date.today()
    events_until = today + datetime.timedelta(weeks=4)

    datetime_now = datetime.datetime.now().strftime("%Y%m%d%Hh")

    os.makedirs(data_dir, exist_ok=True)

    local_file_paths = []
    for city in cities:
        print(f"Fetching events for {city}...")
        for response in paginated_getter(api_key, city, events_until, country_code):
            page_number = response["page"]["number"]
            file_name = f"{datetime_now}_events_pag{str(page_number).zfill(3)}_{country_code}_{city.lower()}.json"
            local_file_path = save_events_to_file(response, data_dir, file_name)
            local_file_paths.append(local_file_path)

    for file_path in local_file_paths:
        upload_to_gcs(file_path)



if __name__ == '__main__':
    main()
# Out:
# Fetching events for Eindhoven...
# Data successfully written to data/2025041113h_events_pag001_NL_eindhoven.json
# Retrieved page 1 with 20 event(s).
# Fetching events for Amsterdam...
# Data successfully written to data/2025041113h_events_pag001_NL_amsterdam.json
# Retrieved page 1 with 20 event(s).
# Uploading data/2025041113h_events_pag001_NL_eindhoven.json to ticketmaster_bucket (Attempt 1)...
# Uploaded: gs://ticketmaster_bucket/2025041113h_events_pag001_NL_eindhoven.json
# Verification successful for 2025041113h_events_pag001_NL_eindhoven.json
# Uploading data/2025041113h_events_pag001_NL_amsterdam.json to ticketmaster_bucket (Attempt 1)...
# Uploaded: gs://ticketmaster_bucket/2025041113h_events_pag001_NL_amsterdam.json
# Verification successful for 2025041113h_events_pag001_NL_amsterdam.json

# %%
local_file_paths
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 local_file_paths
#
# NameError: name 'local_file_paths' is not defined

# %%
import requests
import pandas as pd
import dlt
import os
import json
import datetime

BASE_API_URL = "https://app.ticketmaster.com/discovery/v2"
EVENTS_ENDPOINT = f"{BASE_API_URL}/events.json"

def paginated_getter(API_KEY: str, city: str, events_until: datetime.date, country_code: str = "NL"):
    """
    Generator function to retrieve paginated events from Ticketmaster API.
    """

    page_number = 1
    MAX_PAGES = 1
    PAGE_SIZE = 2

    while page_number <= MAX_PAGES:
        params = {
            "page": page_number,
            # "size": PAGE_SIZE,
            "countryCode": country_code,
            "city": city,
            "endDateTime": events_until.strftime("%Y-%m-%dT%H:%M:%SZ"), # Filter events with a start date before until date
            "apikey": API_KEY
        }

        try:
            response = requests.get(EVENTS_ENDPOINT, params=params)
            response.raise_for_status()
            page_json = response.json()
            events = page_json.get("_embedded", {}).get("events", [])

            if not page_json:
                print(f'No more events available after page {page_number}.')
                break
            
            yield page_json
            print(f'Retrieved page {page_number} with {len(events)} event(s).')

            page_number += 1
            
        except requests.exceptions.HTTPError as e:
            # raise(f"HTTP error occurred: {e}")
            print(f"HTTP error occurred: {e}")
            break
        except requests.exceptions.RequestException as e:
            print(f"Request exception occurred: {e}")
            break

if __name__ == '__main__':

    API_KEY = os.environ.get("TICKETMASTER_API_KEY")
    COUNTRY_CODE = "NL"
    DATA_DIR = "data"

    cities = ["Eindhoven", "Amsterdam"]
    today = datetime.date.today()
    events_until = today + datetime.timedelta(weeks=4)

    datetime_now = datetime.datetime.now().strftime("%Y%m%d%HH")

    for city in cities:
        for response in paginated_getter(
            API_KEY,
            city=city,
            events_until=events_until,
            country_code=COUNTRY_CODE
        ):

            page_number = response["page"]["number"]

            file_name = f"{datetime_now}_events_pag{str(page_number).zfill(3)}_{COUNTRY_CODE}_{city}.json"
            file_name = file_name.lower()

            with open(os.path.join(DATA_DIR, file_name), 'w') as json_file:
                json.dump(response, json_file, indent=4)
# Out:
# Retrieved page 1 with 0 event(s).
# Retrieved page 1 with 20 event(s).

# %%
import json

with open("events.json", 'w') as json_file:
    json.dump(events, json_file, indent=4)

print(f"Data successfully written")
# Out:
# Data successfully written

# %%
generators_pipeline = dlt.pipeline(
    destination='duckdb', 
    dataset_name='generators'
)


# we can load any generator to a table at the pipeline destination as follows:
generators_pipeline.run(paginated_getter(),
            table_name="events",
            write_disposition="replace")

# %%
import pandas as pd

df = pd.json_normalize(events)
# Out:
#                                         name   type                  id  \
# 0  Temple Fang + Mojo & The Kitchen Brothers  event   Z698xZbpZ1kFkZ-7a
# 1                                STRIPE-FEST  event  Z698xZbpZ16v77_4aA
#
#     test                                                url locale  \
# 0  False  https://www.ticketmaster.nl/event/temple-fang-...  en-us
# 1  False  https://www.ticketmaster.nl/event/stripe-fest-...  en-us
#
#                                               images  \
# 0  [{'ratio': '16_9', 'url': 'https://s1.ticketm....
# 1  [{'ratio': '4_3', 'url': 'https://s1.ticketm.n...
#
#                                      classifications  \
# 0  [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 1  [{'primary': False, 'segment': {'id': 'KZFzniw...
#
#                                  promoters sales.public.startDateTime  ...  \
# 0  [{'id': '3049', 'name': 'De Effenaar'}]       2024-11-21T09:00:00Z  ...
# 1    [{'id': '5609', 'name': 'Fiesta BV'}]       2024-12-20T09:00:00Z  ...
#
#    ticketing.safeTix.enabled  ticketing.id  \
# 0                      False     ticketing
# 1                      False     ticketing
#
#                                     _links.self.href  \
# 0  /discovery/v2/events/Z698xZbpZ1kFkZ-7a?locale=...
# 1  /discovery/v2/events/Z698xZbpZ16v77_4aA?locale...
#
#                                   _links.attractions  \
# 0  [{'href': '/discovery/v2/attractions/K8vZ9179B...
# 1  [{'href': '/discovery/v2/attractions/K8vZ917qP...
#
#                                        _links.venues  \
# 0  [{'href': '/discovery/v2/venues/Z598xZbpZd6v7?...
# 1  [{'href': '/discovery/v2/venues/Z598xZbpZkkae?...
#
#                                     _embedded.venues  \
# 0  [{'name': 'Effenaar', 'type': 'venue', 'id': '...
# 1  [{'name': 'Ketelhuisplein / Strijp-S', 'type':...
#
#                                _embedded.attractions  \
# 0  [{'name': 'Temple Fang', 'type': 'attraction',...
# 1  [{'name': 'STRIPE-FEST', 'type': 'attraction',...
#
#    dates.access.startDateTime  dates.access.startApproximate  \
# 0                         NaN                            NaN
# 1        2025-05-24T12:30:00Z                          False
#
#    dates.access.endApproximate
# 0                          NaN
# 1                        False
#
# [2 rows x 37 columns]

# %%
import requests

BASE_API_URL = "https://app.ticketmaster.com/discovery/v2"
URL = f"{BASE_URL}/events.json"
MAX_PAGES = 2

def paginated_getter():
    page_number = 1

    while True:

        # Set the parameters for the request
        params = {
            "page": page_number,
            "size": 1,
            "countryCode": "NL",
            "city": "Eindhoven",
            "radius": 50,
            "unit": "km",
            "apikey": API_KEY
        }

        # Make the GET request to the API
        response = requests.get(URL, params=params)
        response.raise_for_status()  # Raise an HTTP Error for bad responses
        page_json = response.json()
        page_data = page_json.get("_embedded", {}).get("events", [])

        # If the page has no records, stop iterating
        if (len(page_data) > 0) & (page_number <= MAX_PAGES):
            yield page_data
            print(f'got page number {page_number} with {len(page_data)} records')
            page_number += 1
        else:
            # No more data, break the loop
            break

if __name__ == '__main__':
    # Use the generator to iterate over pages
    for page_data in paginated_getter():
        # Process each page as needed
        print("page_data", page_data)
# Out:
# page_data [{'name': 'James Leg', 'type': 'event', 'id': 'Z698xZbpZ17GF-t', 'test': False, 'url': 'https://www.ticketmaster.nl/event/james-leg-tickets/308869?language=en-us', 'locale': 'en-us', 'images': [{'ratio': '4_3', 'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_CUSTOM.jpg', 'width': 305, 'height': 225, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_RECOMENDATION_16_9.jpg', 'width': 100, 'height': 56, 'fallback': False}, {'ratio': '1_1', 'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_SOURCE', 'width': 720, 'height': 720, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_ARTIST_PAGE_3_2.jpg', 'width': 305, 'height': 203, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_TABLET_LANDSCAPE_3_2.jpg', 'width': 1024, 'height': 683, 'fallback': True}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_RETINA_LANDSCAPE_16_9.jpg', 'width': 1136, 'height': 639, 'fallback': True}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_RETINA_PORTRAIT_16_9.jpg', 'width': 640, 'height': 360, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_TABLET_LANDSCAPE_LARGE_16_9.jpg', 'width': 2048, 'height': 1152, 'fallback': True}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_RETINA_PORTRAIT_3_2.jpg', 'width': 640, 'height': 427, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/c/fbc/b293c0ad-c904-4215-bc59-8d7f2414dfbc_106141_TABLET_LANDSCAPE_16_9.jpg', 'width': 1024, 'height': 576, 'fallback': True}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/93a/312622a1-4c6a-4ace-8fbe-b7670aa2493a_EVENT_DETAIL_PAGE_16_9.jpg', 'width': 205, 'height': 115, 'fallback': False}], 'sales': {'public': {'startDateTime': '2024-09-10T08:00:00Z', 'startTBD': False, 'startTBA': False, 'endDateTime': '2025-04-24T21:00:00Z'}}, 'dates': {'start': {'localDate': '2025-04-24', 'localTime': '20:30:00', 'dateTime': '2025-04-24T18:30:00Z', 'dateTBD': False, 'dateTBA': False, 'timeTBA': False, 'noSpecificTime': False}, 'timezone': 'Europe/Amsterdam', 'status': {'code': 'onsale'}, 'spanMultipleDays': False}, 'classifications': [{'primary': True, 'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'}, 'genre': {'id': 'KnvZfZ7vAvl', 'name': 'Other'}, 'subGenre': {'id': 'KZazBEonSMnZfZ7vk1I', 'name': 'Other'}, 'family': False}], 'promoter': {'id': '3049', 'name': 'De Effenaar'}, 'promoters': [{'id': '3049', 'name': 'De Effenaar'}], 'seatmap': {'staticUrl': 'https://media.ticketmaster.eu/netherlands/8955f6705b4384b3c3bc05e10815ecf3.jpg', 'id': 'seatmap'}, 'ticketing': {'safeTix': {'enabled': False}, 'id': 'ticketing'}, '_links': {'self': {'href': '/discovery/v2/events/Z698xZbpZ17GF-t?locale=en-us'}, 'attractions': [{'href': '/discovery/v2/attractions/K8vZ91721T7?locale=en-us'}], 'venues': [{'href': '/discovery/v2/venues/Z598xZbpZ77v7?locale=en-us'}]}, '_embedded': {'venues': [{'name': 'Cafe Wilhelmina', 'type': 'venue', 'id': 'Z598xZbpZ77v7', 'test': False, 'url': 'https://www.ticketmaster.nl/venue/cafe-wilhelmina-eindhoven-tickets/wilhelmina/115', 'locale': 'en-us', 'images': [{'ratio': '16_9', 'url': 'https://media.ticketmaster.eu/netherlands/b428b4403d881478983fbdf257eaed2e.png', 'width': 205, 'height': 115, 'fallback': False}], 'postalCode': '5611 HE', 'timezone': 'Europe/Amsterdam', 'city': {'name': 'Eindhoven'}, 'country': {'name': 'Netherlands', 'countryCode': 'NL'}, 'address': {'line1': 'Wilhelminaplein 6'}, 'location': {'longitude': '5.4718', 'latitude': '51.43788'}, 'upcomingEvents': {'mfx-nl': 4, '_total': 4, '_filtered': 0}, '_links': {'self': {'href': '/disco ...
# got page number 1 with 1 records
# page_data [{'name': 'Fresku - Homecoming show', 'type': 'event', 'id': 'Z698xZbpZ16v44Pz_U', 'test': False, 'url': 'https://www.ticketmaster.nl/event/fresku-homecoming-show-tickets/1555978676?language=en-us', 'locale': 'en-us', 'images': [{'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/e62/a5d65859-3742-43b7-a5d8-b5d4ca7b5e62_RECOMENDATION_16_9.jpg', 'width': 100, 'height': 56, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/e62/a5d65859-3742-43b7-a5d8-b5d4ca7b5e62_RETINA_PORTRAIT_3_2.jpg', 'width': 640, 'height': 427, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/e62/a5d65859-3742-43b7-a5d8-b5d4ca7b5e62_TABLET_LANDSCAPE_3_2.jpg', 'width': 1024, 'height': 683, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/e62/a5d65859-3742-43b7-a5d8-b5d4ca7b5e62_RETINA_LANDSCAPE_16_9.jpg', 'width': 1136, 'height': 639, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/e62/a5d65859-3742-43b7-a5d8-b5d4ca7b5e62_ARTIST_PAGE_3_2.jpg', 'width': 305, 'height': 203, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/e62/a5d65859-3742-43b7-a5d8-b5d4ca7b5e62_TABLET_LANDSCAPE_16_9.jpg', 'width': 1024, 'height': 576, 'fallback': False}, {'ratio': '4_3', 'url': 'https://s1.ticketm.net/dam/a/e62/a5d65859-3742-43b7-a5d8-b5d4ca7b5e62_CUSTOM.jpg', 'width': 305, 'height': 225, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/e62/a5d65859-3742-43b7-a5d8-b5d4ca7b5e62_SOURCE', 'width': 2426, 'height': 1365, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/e62/a5d65859-3742-43b7-a5d8-b5d4ca7b5e62_EVENT_DETAIL_PAGE_16_9.jpg', 'width': 205, 'height': 115, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/e62/a5d65859-3742-43b7-a5d8-b5d4ca7b5e62_TABLET_LANDSCAPE_LARGE_16_9.jpg', 'width': 2048, 'height': 1152, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/e62/a5d65859-3742-43b7-a5d8-b5d4ca7b5e62_RETINA_PORTRAIT_16_9.jpg', 'width': 640, 'height': 360, 'fallback': False}, {'url': 'https://s1.ticketm.net/dam/a/6be/e0022838-2394-4db5-95a0-ca18229fd6be_SOURCE', 'width': 1260, 'height': 578, 'fallback': False}], 'sales': {'public': {'startDateTime': '2024-11-25T09:00:00Z', 'startTBD': False, 'startTBA': False, 'endDateTime': '2025-04-25T21:00:00Z'}}, 'dates': {'start': {'localDate': '2025-04-25', 'localTime': '19:30:00', 'dateTime': '2025-04-25T17:30:00Z', 'dateTBD': False, 'dateTBA': False, 'timeTBA': False, 'noSpecificTime': False}, 'timezone': 'Europe/Amsterdam', 'status': {'code': 'onsale'}, 'spanMultipleDays': False}, 'classifications': [{'primary': True, 'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'}, 'genre': {'id': 'KnvZfZ7vAvl', 'name': 'Other'}, 'subGenre': {'id': 'KZazBEonSMnZfZ7vk1I', 'name': 'Other'}, 'family': False}], 'promoter': {'id': '3049', 'name': 'De Effenaar'}, 'promoters': [{'id': '3049', 'name': 'De Effenaar'}], 'seatmap': {'staticUrl': 'https://media.ticketmaster.eu/netherlands/5ba9e1a79b253940e0cdbaebc068f86e.jpg', 'id': 'seatmap'}, 'ticketing': {'safeTix': {'enabled': False}, 'id': 'ticketing'}, '_links': {'self': {'href': '/discovery/v2/events/Z698xZbpZ16v44Pz_U?locale=en-us'}, 'attractions': [{'href': '/discovery/v2/attractions/K8vZ9172cA0?locale=en-us'}], 'venues': [{'href': '/discovery/v2/venues/Z598xZbpZd6v7?locale=en-us'}]}, '_embedded': {'venues': [{'name': 'Effenaar', 'type': 'venue', 'id': 'Z598xZbpZd6v7', 'test': False, 'url': 'https://www.ticketmaster.nl/venue/effenaar-eindhoven-tickets/effe/115', 'locale': 'en-us', 'images': [{'ratio': '16_9', 'url': 'https://media.ticketmaster.eu/netherlands/134544ec55012e9d88b67c7346863d42.png', 'width': 205, 'height': 115, 'fallback': False}], 'postalCode': '5611 CK', 'timezone': 'Europe/Amsterdam', 'city': {'name': 'Eindhoven'}, 'country': {'name': 'Netherlands', 'countryCode': 'NL'}, 'address': {'line1': 'Dommelstraat 2'}, 'location': {'longitude':  ...
# got page number 2 with 1 records

# %%
import os
import sys
import urllib.request
from concurrent.futures import ThreadPoolExecutor
from google.cloud import storage
from google.api_core.exceptions import NotFound, Forbidden
import time

# Change this to your bucket name
BUCKET_NAME = "ticketmaster_bucket"

# If you authenticated through the GCP SDK you can comment out these two lines
CREDENTIALS_FILE = os.environ["GOOGLE_APPLICATION_CREDENTIALS"]
client = storage.Client.from_service_account_json(CREDENTIALS_FILE)

BASE_API_URL = "https://app.ticketmaster.com/discovery/v2"
EVENTS_ENDPOINT = f"{BASE_API_URL}/events.json"
CITIES = ["Eindhoven", "Utrecht", "Amsterdam"]

bucket = client.bucket(BUCKET_NAME)


MAX_PAGES = 2
PAGE_SIZE = 1
COUNTRY_CODE = "NL"

# %%
import os
import sys
import urllib.request
from concurrent.futures import ThreadPoolExecutor
from google.cloud import storage
from google.api_core.exceptions import NotFound, Forbidden
import time

# Change this to your bucket name
BUCKET_NAME = "ticketmaster_bucket"

# If you authenticated through the GCP SDK you can comment out these two lines
CREDENTIALS_FILE = os.environ["GOOGLE_APPLICATION_CREDENTIALS"]
client = storage.Client.from_service_account_json(CREDENTIALS_FILE)

bucket = client.bucket(BUCKET_NAME)

def create_bucket(bucket_name):
    try:
        # Get bucket details
        bucket = client.get_bucket(bucket_name)

        # Check if the bucket belongs to the current project
        project_bucket_ids = [bckt.id for bckt in client.list_buckets()]
        if bucket_name in project_bucket_ids:
            print(
                f"Bucket '{bucket_name}' exists and belongs to your project. Proceeding..."
            )
        else:
            print(
                f"A bucket with the name '{bucket_name}' already exists, but it does not belong to your project."
            )
            sys.exit(1)

    except NotFound:
        # If the bucket doesn't exist, create it
        bucket = client.create_bucket(bucket_name)
        print(f"Created bucket '{bucket_name}'")
    except Forbidden:
        # If the request is forbidden, it means the bucket exists but you don't have access to see details
        print(
            f"A bucket with the name '{bucket_name}' exists, but it is not accessible. Bucket name is taken. Please try a different bucket name."
        )
        sys.exit(1)

def verify_gcs_upload(blob_name):
    return storage.Blob(bucket=bucket, name=blob_name).exists(client)

def upload_to_gcs(file_path, max_retries=3):
    blob_name = os.path.basename(file_path)
    blob = bucket.blob(blob_name)

    create_bucket(BUCKET_NAME)

    for attempt in range(max_retries):
        try:
            print(f"Uploading {file_path} to {BUCKET_NAME} (Attempt {attempt + 1})...")
            blob.upload_from_filename(file_path)
            print(f"Uploaded: gs://{BUCKET_NAME}/{blob_name}")

            if verify_gcs_upload(blob_name):
                print(f"Verification successful for {blob_name}")
                return
            else:
                print(f"Verification failed for {blob_name}, retrying...")
        except Exception as e:
            print(f"Failed to upload {file_path} to GCS: {e}")

        time.sleep(5)

    print(f"Giving up on {file_path} after {max_retries} attempts.")

# %%
create_bucket(BUCKET_NAME)
# Out:
# Bucket 'ticketmaster_bucket' exists and belongs to your project. Proceeding...

# %%
verify_gcs_upload

# %%
@dlt.source(name="rides")
def download_parquet():
     for month in range(1,7):
      file_name = f"yellow_tripdata_2024-0{month}.parquet"

      url = f"https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-0{month}.parquet"
      response = requests.get(url)

      df = pd.read_parquet(BytesIO(response.content))

      # Return the dataframe as a dlt resource for ingestion
      yield dlt.resource(df, name=file_name)

# %%
import dlt

# define the connection to load to.
# We now use duckdb, but you can switch to Bigquery later
generators_pipeline = dlt.pipeline(
    destination='duckdb', 
    dataset_name='generators'
)


# we can load any generator to a table at the pipeline destination as follows:
generators_pipeline.run(paginated_getter(),
            table_name="events",
            write_disposition="replace")
# Out:
# got page number 1 with 1 records
# got page number 2 with 1 records
# LoadInfo(pipeline=<dlt.pipeline.pipeline.Pipeline object at 0x7fd1413686e0>, metrics={'1744357845.2857563': [{'started_at': DateTime(2025, 4, 11, 7, 50, 46, 444082, tzinfo=Timezone('UTC')), 'finished_at': DateTime(2025, 4, 11, 7, 50, 47, 986582, tzinfo=Timezone('UTC')), 'job_metrics': {'events___embedded__attractions__external_links__homepage.8d95b147a7.insert_values': LoadJobMetrics(job_id='events___embedded__attractions__external_links__homepage.8d95b147a7.insert_values', file_path='/home/lars/.dlt/pipelines/dlt_ipykernel_launcher/load/normalized/1744357845.2857563/started_jobs/events___embedded__attractions__external_links__homepage.8d95b147a7.0.insert_values', table_name='events___embedded__attractions__external_links__homepage', started_at=DateTime(2025, 4, 11, 7, 50, 46, 740577, tzinfo=Timezone('UTC')), finished_at=DateTime(2025, 4, 11, 7, 50, 46, 770689, tzinfo=Timezone('UTC')), state='completed', remote_url=None), 'events___embedded__attractions__external_links__musicbrainz.e2aa10222c.insert_values': LoadJobMetrics(job_id='events___embedded__attractions__external_links__musicbrainz.e2aa10222c.insert_values', file_path='/home/lars/.dlt/pipelines/dlt_ipykernel_launcher/load/normalized/1744357845.2857563/started_jobs/events___embedded__attractions__external_links__musicbrainz.e2aa10222c.0.insert_values', table_name='events___embedded__attractions__external_links__musicbrainz', started_at=DateTime(2025, 4, 11, 7, 50, 46, 739839, tzinfo=Timezone('UTC')), finished_at=DateTime(2025, 4, 11, 7, 50, 46, 768637, tzinfo=Timezone('UTC')), state='completed', remote_url=None), 'events__promoters.094ee13330.insert_values': LoadJobMetrics(job_id='events__promoters.094ee13330.insert_values', file_path='/home/lars/.dlt/pipelines/dlt_ipykernel_launcher/load/normalized/1744357845.2857563/started_jobs/events__promoters.094ee13330.0.insert_values', table_name='events__promoters', started_at=DateTime(2025, 4, 11, 7, 50, 46, 735155, tzinfo=Timezone('UTC')), finished_at=DateTime(2025, 4, 11, 7, 50, 46, 774657, tzinfo=Timezone('UTC')), state='completed', remote_url=None), 'events__images.163cc91dca.insert_values': LoadJobMetrics(job_id='events__images.163cc91dca.insert_values', file_path='/home/lars/.dlt/pipelines/dlt_ipykernel_launcher/load/normalized/1744357845.2857563/started_jobs/events__images.163cc91dca.0.insert_values', table_name='events__images', started_at=DateTime(2025, 4, 11, 7, 50, 46, 738980, tzinfo=Timezone('UTC')), finished_at=DateTime(2025, 4, 11, 7, 50, 46, 783659, tzinfo=Timezone('UTC')), state='completed', remote_url=None), 'events___embedded__attractions__external_links__twitter.bbf6325205.insert_values': LoadJobMetrics(job_id='events___embedded__attractions__external_links__twitter.bbf6325205.insert_values', file_path='/home/lars/.dlt/pipelines/dlt_ipykernel_launcher/load/normalized/1744357845.2857563/started_jobs/events___embedded__attractions__external_links__twitter.bbf6325205.0.insert_values', table_name='events___embedded__attractions__external_links__twitter', started_at=DateTime(2025, 4, 11, 7, 50, 46, 741250, tzinfo=Timezone('UTC')), finished_at=DateTime(2025, 4, 11, 7, 50, 46, 778098, tzinfo=Timezone('UTC')), state='completed', remote_url=None), 'events___embedded__attractions.6c0208a93c.insert_values': LoadJobMetrics(job_id='events___embedded__attractions.6c0208a93c.insert_values', file_path='/home/lars/.dlt/pipelines/dlt_ipykernel_launcher/load/normalized/1744357845.2857563/started_jobs/events___embedded__attractions.6c0208a93c.0.insert_values', table_name='events___embedded__attractions', started_at=DateTime(2025, 4, 11, 7, 50, 46, 744105, tzinfo=Timezone('UTC')), finished_at=DateTime(2025, 4, 11, 7, 50, 46, 787392, tzinfo=Timezone('UTC')), state='completed', remote_url=None), 'events.fa524c5df3.insert_values': LoadJobMetrics(job_id='events.fa524c5df3.insert_values', file_path='/home/lars/.dlt/pipelines/dlt_ipykernel_launcher/load/normalized/1744357845.2857563/started_jobs/events.fa524c5df3.0.insert_values', tab ...

# %%
import duckdb

conn = duckdb.connect(f"{generators_pipeline.pipeline_name}.duckdb")

# let's see the tables
conn.sql(f"SET search_path = '{generators_pipeline.dataset_name}'")
print('Loaded tables: ')
display(conn.sql("show tables"))
# Out:
# Loaded tables:
# ┌────────────────────────────────────────────────────────────────┐
# │                              name                              │
# │                            varchar                             │
# ├────────────────────────────────────────────────────────────────┤
# │ _dlt_loads                                                     │
# │ _dlt_pipeline_state                                            │
# │ _dlt_version                                                   │
# │ events                                                         │
# │ events___embedded__attractions                                 │
# │ events___embedded__attractions__classifications                │
# │ events___embedded__attractions__external_links__facebook       │
# │ events___embedded__attractions__external_links__homepage       │
# │ events___embedded__attractions__external_links__instagram      │
# │ events___embedded__attractions__external_links__itunes         │
# │                           ·                                    │
# │                           ·                                    │
# │                           ·                                    │
# │ http_download___embedded__attractions__external_links__wiki    │
# │ http_download___embedded__attractions__external_links__youtube │
# │ http_download___embedded__attractions__images                  │
# │ http_download___embedded__venues                               │
# │ http_download___embedded__venues__images                       │
# │ http_download___links__attractions                             │
# │ http_download___links__venues                                  │
# │ http_download__classifications                                 │
# │ http_download__images                                          │
# │ http_download__promoters                                       │
# ├────────────────────────────────────────────────────────────────┤
# │                       45 rows (20 shown)                       │
# └────────────────────────────────────────────────────────────────┘

# %%
events = conn.sql("SELECT * FROM events___embedded__venues").df()
display(events)
# Out:
#               name   type             id   test  \
# 0  Cafe Wilhelmina  venue  Z598xZbpZ77v7  False
# 1         Effenaar  venue  Z598xZbpZd6v7  False
#
#                                                  url locale postal_code  \
# 0  https://www.ticketmaster.nl/venue/cafe-wilhelm...  en-us     5611 HE
# 1  https://www.ticketmaster.nl/venue/effenaar-ein...  en-us     5611 CK
#
#            timezone city__name country__name  ... location__longitude  \
# 0  Europe/Amsterdam  Eindhoven   Netherlands  ...              5.4718
# 1  Europe/Amsterdam  Eindhoven   Netherlands  ...             5.48362
#
#   location__latitude upcoming_events__mfx_nl upcoming_events___total  \
# 0           51.43788                       4                       4
# 1           51.44158                      74                      77
#
#    upcoming_events___filtered  \
# 0                           0
# 1                           0
#
#                                 _links__self__href  _dlt_parent_id  \
# 0  /discovery/v2/venues/Z598xZbpZ77v7?locale=en-us  wR5G4Jf+6NPmfg
# 1  /discovery/v2/venues/Z598xZbpZd6v7?locale=en-us  pHtuvPyux73eiw
#
#   _dlt_list_idx         _dlt_id  upcoming_events__universe
# 0             0  35gKxNeOnSiOOg                       <NA>
# 1             0  uR+sFd2m40nVkQ                          3
#
# [2 rows x 22 columns]

# %%
conn.sql("SELECT * FROM events").df()

# %%
import dlt
from dlt.sources.rest_api import rest_api_source

url = f"{BASE_URL}/events.json"

# Set the parameters for the request
params = {
    "size": 5,
    "countryCode": "NL",
    "city": "Eindhoven",
    "radius": 50,
    "unit": "km",
    "apikey": API_KEY
}

# Configure the REST API source for Ticketmaster
ticketmaster_source = rest_api_source({
    "client": {
        "base_url": BASE_URL,
        "auth": {
            "token": API_KEY,
        },
        "paginator": {
            "type": "json_link",
            "next_url_path": "_links.next",
        },
    },
    "resources": [
        # "events" will be used as the endpoint path, the resource name,
        # and the table name in the destination.
        "events",
        {
            "name": "event_details",
            "endpoint": {
                "path": "/events.json",
                "params": {
                    "size": 5,
                    "countryCode": "NL",
                    "city": "Eindhoven",
                    "radius": 50,
                    "unit": "km",
                    "apikey": API_KEY
                }
            },
        }
    ],
})

# Initialize the pipeline
pipeline = dlt.pipeline(
    pipeline_name="ticketmaster_rest_api",
    destination="duckdb",
    dataset_name="ticketmaster_data",
)

# Run the pipeline to load data
load_info = pipeline.run(ticketmaster_source)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/dlt/extract/pipe_iterator.py:277, in PipeIterator._get_source_item(self)
#     275 set_current_pipe_name(pipe.name)
# --> 277 pipe_item = next(gen)
#     278 if pipe_item is not None:
#     279     # full pipe item may be returned, this is used by ForkPipe step
#     280     # to redirect execution of an item to another pipe
#     281     # else
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/sources/rest_api/__init__.py:314, in create_resources.<locals>.paginate_resource(method, path, params, json, paginator, data_selector, hooks, client, incremental_object, incremental_param, incremental_cursor_transform)
#     307     params = _set_incremental_params(
#     308         params,
#     309         incremental_object,
#     310         incremental_param,
#     311         incremental_cursor_transform,
#     312     )
# --> 314 yield from client.paginate(
#     315     method=method,
#     316     path=path,
#     317     params=params,
#     318     json=json,
#     319     paginator=paginator,
#     320     data_selector=data_selector,
#     321     hooks=hooks,
#     322 )
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/sources/helpers/rest_client/client.py:224, in RESTClient.paginate(self, path, method, params, json, auth, paginator, data_selector, hooks, **kwargs)
#     223 try:
# --> 224     response = self._send_request(request, **kwargs)
#     225 except IgnoreResponseException:
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/sources/helpers/rest_client/client.py:140, in RESTClient._send_request(self, request, **kwargs)
#     139 send_kwargs.update(**kwargs)  #  type: ignore[call-arg]
# --> 140 return self.session.send(prepared_request, **send_kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/tenacity/__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~/anaconda3/lib/python3.12/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#
# File ~/anaconda3/lib/python3.12/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#
# File ~/anaconda3/lib/python3.12/concurrent/futures/_base.py:449, in Future.result(self, timeout)
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#
# File ~/anaconda3/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     400 try:
# --> 401     raise self._exception
#     402 finally:
#     403     # Break a reference cycle with the exception in self._exception
#
# File ~/anaconda3/lib/python3.12/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     381 try:
# --> 382     result = fn(*args, **kwargs)
#     383 except BaseException:  # noqa: B902
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/sources/helpers/requests/session.py:61, in Session.send(self, request, **kwargs)
#      60 kwargs.setdefault("timeout", self.timeout)
# ---> 61 return super().send(request, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/requests/sessions.py:710, in Session.send(self, request, **kwargs)
#     709 # Response manipulation hooks
# --> 710 r = dispatch_hook("response", hooks, r, **kwargs)
#     712 # Persist cookies
#
# File ~/anaconda3/lib/python3.12/site-packages/requests/hooks.py:30, in dispatch_hook(key, hooks, hook_data, **kwargs)
#      29 for hook in hooks:
# ---> 30     _hook_data = hook(hook_data, **kwargs)
#      31     if _hook_data is not None:
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/sources/helpers/rest_client/client.py:315, in raise_for_status(response, *args, **kwargs)
#     314 def raise_for_status(response: Response, *args: Any, **kwargs: Any) -> None:
# --> 315     response.raise_for_status()
#
# File ~/anaconda3/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 401 Client Error: Unauthorized for url: https://app.ticketmaster.com/discovery/v2/events
#
# The above exception was the direct cause of the following exception:
#
# ResourceExtractionError                   Traceback (most recent call last)
# File ~/anaconda3/lib/python3.12/site-packages/dlt/pipeline/pipeline.py:470, in Pipeline.extract(self, data, table_name, parent_table_name, write_disposition, columns, primary_key, schema, max_parallel_items, workers, table_format, schema_contract, refresh)
#     468         raise SourceExhausted(source.name)
# --> 470     self._extract_source(
#     471         extract_step,
#     472         source,
#     473         max_parallel_items,
#     474         workers,
#     475         refresh=refresh or self.refresh,
#     476     )
#     478 # this will update state version hash so it will not be extracted again by with_state_sync
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/pipeline/pipeline.py:1238, in Pipeline._extract_source(self, extract, source, max_parallel_items, workers, refresh, load_package_state_update)
#    1237 # extract into pipeline schema
# -> 1238 load_id = extract.extract(
#    1239     source, max_parallel_items, workers, load_package_state_update=load_package_state_update
#    1240 )
#    1242 # update live schema but not update the store yet
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/extract/extract.py:435, in Extract.extract(self, source, max_parallel_items, workers, load_package_state_update)
#     433             reset_resource_state(resource.name)
# --> 435 self._extract_single_source(
#     436     load_id,
#     437     source,
#     438     max_parallel_items=max_parallel_items,
#     439     workers=workers,
#     440 )
#     441 commit_load_package_state()
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/extract/extract.py:358, in Extract._extract_single_source(self, load_id, source, max_parallel_items, workers)
#     357 collector.update("Resources", 0, total_gens)
# --> 358 for pipe_item in pipes:
#     359     curr_gens = len(pipes._sources)
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/extract/pipe_iterator.py:162, in PipeIterator.__next__(self)
#     160 if pipe_item is None:
#     161     # if none then take element from the newest source
# --> 162     pipe_item = self._get_source_item()
#     164 if pipe_item is None:
#     165     # Wait for some time for futures to resolve
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/extract/pipe_iterator.py:307, in PipeIterator._get_source_item(self)
#     306 except Exception as ex:
# --> 307     raise ResourceExtractionError(pipe.name, gen, str(ex), "generator") from ex
#
# ResourceExtractionError: In processing pipe events: extraction of resource events in generator paginate_resource caused an exception: 401 Client Error: Unauthorized for url: https://app.ticketmaster.com/discovery/v2/events
#
# The above exception was the direct cause of the following exception:
#
# PipelineStepFailed                        Traceback (most recent call last)
# Cell In[12], line 57
#      50 pipeline = dlt.pipeline(
#      51     pipeline_name="ticketmaster_rest_api",
#      52     destination="duckdb",
#      53     dataset_name="ticketmaster_data",
#      54 )
#      56 # Run the pipeline to load data
# ---> 57 load_info = pipeline.run(ticketmaster_source)
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/pipeline/pipeline.py:225, in with_runtime_trace.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     222     if trace:
#     223         trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
# --> 225     step_info = f(self, *args, **kwargs)
#     226     return step_info
#     227 except Exception as ex:
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/pipeline/pipeline.py:274, in with_config_section.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     266 @wraps(f)
#     267 def _wrap(self: "Pipeline", *args: Any, **kwargs: Any) -> Any:
#     268     # add section context to the container to be used by all configuration without explicit sections resolution
#     269     with inject_section(
#     270         ConfigSectionContext(
#     271             pipeline_name=self.pipeline_name, sections=sections, merge_style=merge_func
#     272         )
#     273     ):
# --> 274         return f(self, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/pipeline/pipeline.py:734, in Pipeline.run(self, data, destination, staging, dataset_name, credentials, table_name, write_disposition, columns, primary_key, schema, loader_file_format, table_format, schema_contract, refresh)
#     732 # extract from the source
#     733 if data is not None:
# --> 734     self.extract(
#     735         data,
#     736         table_name=table_name,
#     737         write_disposition=write_disposition,
#     738         columns=columns,
#     739         primary_key=primary_key,
#     740         schema=schema,
#     741         table_format=table_format,
#     742         schema_contract=schema_contract,
#     743         refresh=refresh or self.refresh,
#     744     )
#     745     self.normalize(loader_file_format=loader_file_format)
#     746     return self.load(destination, dataset_name, credentials=credentials)
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/pipeline/pipeline.py:225, in with_runtime_trace.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     222     if trace:
#     223         trace_step = start_trace_step(trace, cast(TPipelineStep, f.__name__), self)
# --> 225     step_info = f(self, *args, **kwargs)
#     226     return step_info
#     227 except Exception as ex:
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/pipeline/pipeline.py:179, in with_schemas_sync.<locals>._wrap(self, *args, **kwargs)
#     177     self._schema_storage.commit_live_schema(name)
#     178 try:
# --> 179     rv = f(self, *args, **kwargs)
#     180 except Exception:
#     181     # because we committed live schema before calling f, we may safely
#     182     # drop all changes in live schemas
#     183     for name in list(self._schema_storage.live_schemas.keys()):
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/pipeline/pipeline.py:165, in with_state_sync.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     163 should_extract_state = may_extract_state and self.config.restore_from_destination
#     164 with self.managed_state(extract_state=should_extract_state):
# --> 165     return f(self, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/pipeline/pipeline.py:274, in with_config_section.<locals>.decorator.<locals>._wrap(self, *args, **kwargs)
#     266 @wraps(f)
#     267 def _wrap(self: "Pipeline", *args: Any, **kwargs: Any) -> Any:
#     268     # add section context to the container to be used by all configuration without explicit sections resolution
#     269     with inject_section(
#     270         ConfigSectionContext(
#     271             pipeline_name=self.pipeline_name, sections=sections, merge_style=merge_func
#     272         )
#     273     ):
# --> 274         return f(self, *args, **kwargs)
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/pipeline/pipeline.py:491, in Pipeline.extract(self, data, table_name, parent_table_name, write_disposition, columns, primary_key, schema, max_parallel_items, workers, table_format, schema_contract, refresh)
#     489 step_info = self._get_step_info(extract_step)
#     490 current_load_id = step_info.loads_ids[-1] if len(step_info.loads_ids) > 0 else None
# --> 491 raise PipelineStepFailed(
#     492     self,
#     493     "extract",
#     494     current_load_id,
#     495     exc,
#     496     step_info,
#     497 ) from exc
#
# PipelineStepFailed: Pipeline execution failed at stage extract when processing package 1744314775.9828188 with exception:
#
# <class 'dlt.extract.exceptions.ResourceExtractionError'>
# In processing pipe events: extraction of resource events in generator paginate_resource caused an exception: 401 Client Error: Unauthorized for url: https://app.ticketmaster.com/discovery/v2/events

# %%
import dlt

# Initialize a DLT pipeline
pipeline = dlt.pipeline(
    pipeline_name='ticketmaster_events', 
    destination='duckdb', 
    dataset_name='events_data'
)

url = f"{BASE_URL}/events.json"
params = {
    "size": 5,
    "countryCode": "NL",
    "city": "Eindhoven",
    "radius": 50,
    "unit": "km",
    "apikey": API_KEY
}

# Fetch data using DLT's request
@dlt.source(name='ticketmaster_source')
def fetch_ticketmaster_events():
    # Perform a GET request to the API
    response = pipeline.request.get(url, params=params)
    response.raise_for_status()  # Raise an exception for HTTP error codes

    # Return the JSON data
    return response.json()

# Run the pipeline to load data
source = fetch_ticketmaster_events()
pipeline.run(source)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 31
#      28     return response.json()
#      30 # Run the pipeline to load data
# ---> 31 source = fetch_ticketmaster_events()
#      32 pipeline.run(source)
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/extract/decorators.py:199, in DltSourceFactoryWrapper.__call__(self, *args, **kwargs)
#     197         resource.apply_hints(schema_contract=self.schema_contract)
#     198 else:
# --> 199     source = self._deco_f(*args, **kwargs)
#     200 return source
#
# File ~/anaconda3/lib/python3.12/site-packages/dlt/extract/decorators.py:284, in DltSourceFactoryWrapper._wrap.<locals>._wrap(*args, **kwargs)
#     276 pipeline_name = None if not proxy.is_active() else proxy.pipeline().pipeline_name
#     277 with inject_section(
#     278     ConfigSectionContext(
#     279         pipeline_name=pipeline_name,
#    (...)
#     282     )
#     283 ):
# --> 284     rv = conf_f(*args, **kwargs)
#     285     return _eval_rv(rv, schema_copy)
#
# Cell In[8], line 24, in fetch_ticketmaster_events()
#      21 @dlt.source(name='ticketmaster_source')
#      22 def fetch_ticketmaster_events():
#      23     # Perform a GET request to the API
# ---> 24     response = pipeline.request.get(url, params=params)
#      25     response.raise_for_status()  # Raise an exception for HTTP error codes
#      27     # Return the JSON data
#
# AttributeError: 'Pipeline' object has no attribute 'request'

# %%
event_id = "Z698xZbpZ17Ga0g"
url = f"{BASE_URL}/events/{event_id}"

# Set the parameters for the request
params = {
    "apikey": API_KEY
}

# Make the GET request to the Ticketmaster API
response = requests.get(url, params=params)

# Check if the request was successful
if response.status_code == 200:
    # Parse and print the JSON response
    data = response.json()
    print(data)
else:
    print(f"Failed to retrieve data: {response.status_code}")
# Out:
# {'name': 'Allman Brown', 'type': 'event', 'id': 'Z698xZbpZ17Ga0g', 'test': False, 'url': 'https://www.ticketmaster.nl/event/allman-brown-tickets/309935', 'locale': 'en-us', 'images': [{'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_SOURCE', 'width': 1440, 'height': 810, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/c/677/c58dd0af-cda8-49b2-bdaf-068540c3a677_106541_TABLET_LANDSCAPE_LARGE_16_9.jpg', 'width': 2048, 'height': 1152, 'fallback': True}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RETINA_PORTRAIT_3_2.jpg', 'width': 640, 'height': 427, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_ARTIST_PAGE_3_2.jpg', 'width': 305, 'height': 203, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_TABLET_LANDSCAPE_3_2.jpg', 'width': 1024, 'height': 683, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RETINA_LANDSCAPE_16_9.jpg', 'width': 1136, 'height': 639, 'fallback': False}, {'ratio': '4_3', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_CUSTOM.jpg', 'width': 305, 'height': 225, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_TABLET_LANDSCAPE_16_9.jpg', 'width': 1024, 'height': 576, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_EVENT_DETAIL_PAGE_16_9.jpg', 'width': 205, 'height': 115, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RETINA_PORTRAIT_16_9.jpg', 'width': 640, 'height': 360, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RECOMENDATION_16_9.jpg', 'width': 100, 'height': 56, 'fallback': False}], 'sales': {'public': {'startDateTime': '2024-10-11T08:00:00Z', 'startTBD': False, 'startTBA': False, 'endDateTime': '2025-04-12T21:30:00Z'}}, 'dates': {'start': {'localDate': '2025-04-12', 'localTime': '20:00:00', 'dateTime': '2025-04-12T18:00:00Z', 'dateTBD': False, 'dateTBA': False, 'timeTBA': False, 'noSpecificTime': False}, 'timezone': 'Europe/Amsterdam', 'status': {'code': 'onsale'}, 'spanMultipleDays': False}, 'classifications': [{'primary': True, 'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'}, 'genre': {'id': 'KnvZfZ7vAvl', 'name': 'Other'}, 'subGenre': {'id': 'KZazBEonSMnZfZ7vk1I', 'name': 'Other'}, 'family': False}], 'promoter': {'id': '3049', 'name': 'De Effenaar'}, 'promoters': [{'id': '3049', 'name': 'De Effenaar'}], 'seatmap': {'staticUrl': 'https://media.ticketmaster.eu/netherlands/d195eae8433e4ffa15240f13c4d888a8.jpg', 'id': 'seatmap'}, 'ticketing': {'safeTix': {'enabled': False}, 'id': 'ticketing'}, '_links': {'self': {'href': '/discovery/v2/events/Z698xZbpZ17Ga0g?locale=en-us'}, 'attractions': [{'href': '/discovery/v2/attractions/K8vZ917pYgf?locale=en-us'}], 'venues': [{'href': '/discovery/v2/venues/Z598xZbpZA717?locale=en-us'}]}, '_embedded': {'venues': [{'name': "Café 't Rozenknopje", 'type': 'venue', 'id': 'Z598xZbpZA717', 'test': False, 'url': 'https://www.ticketmaster.nl/venue/cafe-t-rozenknopje-eindhoven-tickets/rozen/115', 'locale': 'en-us', 'images': [{'ratio': '16_9', 'url': 'https://media.ticketmaster.eu/netherlands/978a260381e7b83fd87879264597d784.png', 'width': 205, 'height': 115, 'fallback': False}], 'postalCode': '5615 PA', 'timezone': 'Europe/Amsterdam', 'city': {'name': 'Eindhoven'}, 'country': {'name': 'Netherlands', 'countryCode': 'NL'}, 'address': {'line1': 'Hoogstraat 59'}, 'location': {'longitude': '5.47156', 'latitude': '51.43338'}, 'upcomingEvents': {'mfx-nl': 4, '_total': 4, '_filtered': 0}, '_links': {'self': {'href': '/discovery/v2/venues/Z598xZbpZA717?locale=e ...

# %%
response.url
# Out:
# 'https://app.ticketmaster.com/discovery/v2/events/Z698xZbpZ17Ga0g?apikey=xkwIHOr5jYGxFVPOCeIF9JMeP2YPjQzH'

# %%
data
# Out:
# {'name': 'Allman Brown',
#  'type': 'event',
#  'id': 'Z698xZbpZ17Ga0g',
#  'test': False,
#  'url': 'https://www.ticketmaster.nl/event/allman-brown-tickets/309935',
#  'locale': 'en-us',
#  'images': [{'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_SOURCE',
#    'width': 1440,
#    'height': 810,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/c/677/c58dd0af-cda8-49b2-bdaf-068540c3a677_106541_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#    'width': 2048,
#    'height': 1152,
#    'fallback': True},
#   {'ratio': '3_2',
#    'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RETINA_PORTRAIT_3_2.jpg',
#    'width': 640,
#    'height': 427,
#    'fallback': False},
#   {'ratio': '3_2',
#    'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_ARTIST_PAGE_3_2.jpg',
#    'width': 305,
#    'height': 203,
#    'fallback': False},
#   {'ratio': '3_2',
#    'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_TABLET_LANDSCAPE_3_2.jpg',
#    'width': 1024,
#    'height': 683,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RETINA_LANDSCAPE_16_9.jpg',
#    'width': 1136,
#    'height': 639,
#    'fallback': False},
#   {'ratio': '4_3',
#    'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_CUSTOM.jpg',
#    'width': 305,
#    'height': 225,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_TABLET_LANDSCAPE_16_9.jpg',
#    'width': 1024,
#    'height': 576,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_EVENT_DETAIL_PAGE_16_9.jpg',
#    'width': 205,
#    'height': 115,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RETINA_PORTRAIT_16_9.jpg',
#    'width': 640,
#    'height': 360,
#    'fallback': False},
#   {'ratio': '16_9',
#    'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RECOMENDATION_16_9.jpg',
#    'width': 100,
#    'height': 56,
#    'fallback': False}],
#  'sales': {'public': {'startDateTime': '2024-10-11T08:00:00Z',
#    'startTBD': False,
#    'startTBA': False,
#    'endDateTime': '2025-04-12T21:30:00Z'}},
#  'dates': {'start': {'localDate': '2025-04-12',
#    'localTime': '20:00:00',
#    'dateTime': '2025-04-12T18:00:00Z',
#    'dateTBD': False,
#    'dateTBA': False,
#    'timeTBA': False,
#    'noSpecificTime': False},
#   'timezone': 'Europe/Amsterdam',
#   'status': {'code': 'onsale'},
#   'spanMultipleDays': False},
#  'classifications': [{'primary': True,
#    'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#    'genre': {'id': 'KnvZfZ7vAvl', 'name': 'Other'},
#    'subGenre': {'id': 'KZazBEonSMnZfZ7vk1I', 'name': 'Other'},
#    'family': False}],
#  'promoter': {'id': '3049', 'name': 'De Effenaar'},
#  'promoters': [{'id': '3049', 'name': 'De Effenaar'}],
#  'seatmap': {'staticUrl': 'https://media.ticketmaster.eu/netherlands/d195eae8433e4ffa15240f13c4d888a8.jpg',
#   'id': 'seatmap'},
#  'ticketing': {'safeTix': {'enabled': False}, 'id': 'ticketing'},
#  '_links': {'self': {'href': '/discovery/v2/events/Z698xZbpZ17Ga0g?locale=en-us'},
#   'attractions': [{'href': '/discovery/v2/attractions/K8vZ917pYgf?locale=en-us'}],
#   'venues': [{'href': '/discovery/v2/venues/Z598xZbpZA717?locale=en-us'}]},
#  '_embedded': {'venues': [{'name': "Café 't Rozenknopje",
#     'type': 'venue',
#     'id': 'Z598xZbpZA717',
#     'test': False,
#     'url': 'https://www.ticketmaster.nl/venue/cafe-t-rozenknopje-eindhoven-tickets/rozen/115',
#     'locale': 'en-us',
#     'images': [{'ratio': '16_9',
#       'url': 'https://media.ticketmaster.eu/netherlands/978a260381e7b83fd87879264597d784.png',
#       'width': 205,
#       'height': 115,
#       'fallback': False}],
#     'postalCode': '5615 PA',
#     'timezone': 'Europe/Amsterdam',
#     'city': {'name': 'Eindhoven'},
#     'country': {'name': 'Netherlands', 'countryCode': 'NL'},
#     'address': {'line1': 'Hoogstraat 59'},
#     'location': {'longitude': '5.47156', 'latitude': '51.43338'},
#     'upcomingEvents': {'mfx-nl': 4, '_total': 4, '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/venues/Z598xZbpZA717?locale=en-us'}}}],
#   'attractions': [{'name': 'Allman Brown',
#     'type': 'attraction',
#     'id': 'K8vZ917pYgf',
#     'test': False,
#     'url': 'https://www.ticketmaster.com/allman-brown-tickets/artist/2446879',
#     'locale': 'en-us',
#     'externalLinks': {'youtube': [{'url': 'https://www.youtube.com/user/ALLMANBROWN11'}],
#      'twitter': [{'url': 'https://twitter.com/allmanbrown'}],
#      'itunes': [{'url': 'https://music.apple.com/ca/artist/allman-brown/356457912'}],
#      'spotify': [{'url': 'https://open.spotify.com/artist/239Y6QdFqVFfdsw6moqSEN?autoplay=true'}],
#      'facebook': [{'url': 'https://www.facebook.com/AllmanBrownMusic'}],
#      'instagram': [{'url': 'https://www.instagram.com/allmanbrown/'}],
#      'homepage': [{'url': 'https://www.allmanbrown.com/'}]},
#     'images': [{'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_SOURCE',
#       'width': 1440,
#       'height': 810,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/c/677/c58dd0af-cda8-49b2-bdaf-068540c3a677_106541_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#       'width': 2048,
#       'height': 1152,
#       'fallback': True},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RETINA_PORTRAIT_3_2.jpg',
#       'width': 640,
#       'height': 427,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_ARTIST_PAGE_3_2.jpg',
#       'width': 305,
#       'height': 203,
#       'fallback': False},
#      {'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_TABLET_LANDSCAPE_3_2.jpg',
#       'width': 1024,
#       'height': 683,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RETINA_LANDSCAPE_16_9.jpg',
#       'width': 1136,
#       'height': 639,
#       'fallback': False},
#      {'ratio': '4_3',
#       'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_CUSTOM.jpg',
#       'width': 305,
#       'height': 225,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_TABLET_LANDSCAPE_16_9.jpg',
#       'width': 1024,
#       'height': 576,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_EVENT_DETAIL_PAGE_16_9.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RETINA_PORTRAIT_16_9.jpg',
#       'width': 640,
#       'height': 360,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/ee4/8664d563-18d3-4ddd-9acd-82235bf7eee4_RECOMENDATION_16_9.jpg',
#       'width': 100,
#       'height': 56,
#       'fallback': False}],
#     'classifications': [{'primary': True,
#       'segment': {'id': 'KZFzniwnSyZfZ7v7nJ', 'name': 'Music'},
#       'genre': {'id': 'KnvZfZ7vAv6', 'name': 'Country'},
#       'subGenre': {'id': 'KZazBEonSMnZfZ7vAad', 'name': 'Country Folk'},
#       'type': {'id': 'KZAyXgnZfZ7v7la', 'name': 'Individual'},
#       'subType': {'id': 'KZFzBErXgnZfZ7vAde', 'name': 'Singer/Vocalist'},
#       'family': False}],
#     'upcomingEvents': {'mfx-nl': 2,
#      'ticketmaster': 1,
#      '_total': 3,
#      '_filtered': 0},
#     '_links': {'self': {'href': '/discovery/v2/attractions/K8vZ917pYgf?locale=en-us'}}}]}}
